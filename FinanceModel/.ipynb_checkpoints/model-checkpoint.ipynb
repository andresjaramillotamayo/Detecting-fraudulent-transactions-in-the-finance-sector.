# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score , roc_curve, auc, plot_roc_curve, plot_precision_recall_curve
from sklearn import preprocessing
from collections import Counter
from verstack import LGBMTuner
import pickle
import os
import sys
import mlflow

def load_data():
    # Read ResultFraudTest_2023-02-23-16-05.xlsx and create a dataframe
    df = pd.read_excel('data/ResultFraudTest_2023-02-23-16-05.xlsx')
    return df

# %%
# Function to show the distribution of classes
def distribution_classes(df):
    y_counts = df['is_fraud'].value_counts().to_frame('count_y_classes')
    y_counts['percentage_y_classes'] = y_counts['count_y_classes'] / y_counts['count_y_classes'].sum()
    print(y_counts)
    sns.countplot(x='is_fraud', data=df, palette='hls')
    return y_counts

# %%
# Function to extract only the columns that will be used in the model  
def get_variables(df):
    columns = ['calculation','count_zip','count_trans_person','is_fraud'] 
    df = df[columns]
    X = df.iloc[:,:-1]
    y = df.iloc[:,-1] 
    return X, y

# Function to calculate the scale_pos_weight (class_weight parameter in algorithm)
def calc_pos_weight(y):
    counter=Counter(y)
    print(counter)
    scale_pos_weight = counter[0] / counter[1]
    print('scale_pos_weight: %.3f' % scale_pos_weight)
    return scale_pos_weight

# %%
# Function to create the training and test sets
def make_train_test_split(x,y):
    # Create the training and test sets
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, stratify=y, random_state=101)
    print(f'X train set size: {X_train.shape};'f'\nX test set size: {X_test.shape};', f'\ny train set size: {y_train.shape};' f'\ny test set size: {y_test.shape};')
    return X_train, X_test, y_train, y_test

# %%
# Function to calcule the metrics to be used
def eval_metrics(y_test,y_pred):
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    F1score = f1_score(y_test, y_pred)
    return acc, precision, recall, F1score, mse, mae

# Function to report metrics
def report(params,acc,precision,recall,F1score,mse,mae):
    print(f'Best parameters: {params}')
    print(f'Accuracy of LightGBM classifier is: {acc}')
    print(f'Precision Score of LightGBM classifier is: {precision}')
    print(f'Recall Score of LightGBM classifier is: {recall}')
    print(f'F1 Score of LightGBM classifier is: {F1score}')
    print(f'mse: {mse}')
    print(f'mae: {mae}')

# %%
# Function to save the model
def save_best_estimator(estimator, path= 'models',pFile = 'fraud_model.pickle'):
    if not os.path.exists('models'):
        os.makedirs('models')
    with open(os.path.join(path, pFile), 'wb') as file:
        pickle.dump(estimator, file)

# %%
# Function to load the model 
def load_best_estimator(path='models', pFile='estimator.pickle'):
    if not os.path.exists(path):
        return None
    with open(os.path.join(path, pFile), "rb") as file:
        estimator = pickle.load(file)
    return estimator

# %%
# Function to do the manual training of the data, to extract some parameters to be compared
def manual_train_estimator(df):
    mlflow.lightgbm.autolog(disable=True)
    n_leaves = np.linspace(20, 300, 20)
    r_alpha = np.linspace(0.0001, 0.5, 20)
    r_lambda = np.linspace(0.0001, 0.5, 20)
    X, y = get_variables(df)
    X_train, X_test, y_train, y_test = make_train_test_split(X,y)
    scale_pos_weight = calc_pos_weight(y)
    # Create the model
    lst = []
    for i,k,j in zip(n_leaves, r_alpha, r_lambda):
        model = lgb.LGBMClassifier(scale_pos_weight=scale_pos_weight, num_leaves=int(i),reg_alpha= k,reg_lambda = j,boosting_type='gbdt',n_jobs=-1,random_state=101)
        # Fitting the model to the training data
        model.fit(X_train, y_train)
        # Making predictions
        y_pred = model.predict(X_test) 
        params = model.get_params()
        # Model evaluation
        acc, precision, recall, score_f1, mse, mae = eval_metrics(y_test,y_pred)
        lst.append([acc,precision,recall,score_f1,mse,mae])
    return lst

# %%
# Fuction to tune the hyperparameters of the LightGBM algorithm
def get_tuned_params(df):
    mlflow.lightgbm.autolog(disable=True)
    X, y = get_variables(df)
    X_train, X_test, y_train, y_test = make_train_test_split(X,y)
    scale_pos_weight = calc_pos_weight(y)
    
    # Create the model
    tuner=LGBMTuner(scale_pos_weight=scale_pos_weight,metric='f1', trials=1000)
    
    # Fitting the model to the training data
    tuner.fit(X_train, y_train)
    
    # Making predictions
    y_pred = tuner.predict(X_test) 
    
    # Model evaluation
    acc, precision, recall, score_f1, mse, mae = eval_metrics(y_test,y_pred)
    report(tuner.best_params,acc,precision,recall,score_f1,mse,mae)
    
    return tuner.best_params

# %%
# Fuction to train the LightGBM algorithm with the best hyperparameters
def best_train_estimator(df,tuner_model):

    X, y = get_variables(df)
    X_train, X_test, y_train, y_test = make_train_test_split(X,y)
    scale_pos_weight = calc_pos_weight(y)
    
    # Create the model
    params = tuner_model
    model = lgb.LGBMClassifier(scale_pos_weight=scale_pos_weight,boosting_type='gbdt',n_jobs=-1, **params)
    
    # Fitting the model to the training data
    model.fit(X_train, y_train)
    
    # Making predictions
    y_pred = model.predict(X_test) 
    
    # Model evaluation
    acc, precision, recall, score_f1, mse, mae = eval_metrics(y_test,y_pred)
    report(model.get_params(),acc,precision,recall,score_f1,mse,mae)
    
    # Plot graphs
    precision_recall_curve_plot(model,X_test,y_test)
    roc_curve_plot(model,X_test,y_test)
    
    # Save model results
    save_best_estimator(model)
    model.booster_.save_model('models/fraud_model.txt')
    model.booster_.save_model('models/fraud_model.json')
    
    return y_test,y_pred,model,acc,precision,recall,score_f1,mse,mae

# %%
# Fuction to plot the list with the Accuracy, Precision, Recall, F1 Score, MSE and MAE metrics of the model, using seaborn and save the image as png file
def plot_metrics(metric):
    metric = pd.DataFrame(metric)
    metric.columns = ['Accuracy','Precision','Recall','F1 Score','MSE','MAE']
    metric.plot(figsize=(16,12), title='Metrics for each manual training',marker='o',markersize=3)
    plt.style.use('seaborn-v0_8-darkgrid')
    plt.xlabel('Manual Train')
    plt.ylabel('Metrics Value')
    plt.xticks(np.arange(0, 20, 1))
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.legend(title='Metrics')
    if not os.path.exists('images'):
        os.makedirs('images')
    plt.savefig('images/metrics.png',facecolor='white', transparent=False)
    plt.show()

# %%
# Function to plot the confusion matrix
def confusion_matrix_plot(y_test,y_pred):
    cfm = confusion_matrix(y_test, y_pred)
    cm_display = ConfusionMatrixDisplay(confusion_matrix = cfm, display_labels = ['Not Fraud', 'Fraud'])
    plt.style.use('seaborn-v0_8-darkgrid')
    fig, ax = plt.subplots(figsize=(12,12))
    cm_display.plot(ax=ax)
    if not os.path.exists('images'):
        os.makedirs('images')
    plt.savefig('images/confusion_matrix.png',facecolor='white', transparent=False)
    plt.show()
    return cfm

# %%
# Function to plot the roc curve
def roc_curve_plot(model,X_test,y_test):
    plt.style.use('seaborn-v0_8-darkgrid')
    fig, ax = plt.subplots(figsize=(16,12))
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plot_roc_curve(model,X_test,y_test,ax=ax)
    if not os.path.exists('images'):
        os.makedirs('images')
    plt.savefig('images/roc_curve.png',facecolor='white', transparent=False)
    plt.show()

# %%
#Function to plot the Precision - Recall curve
def precision_recall_curve_plot(model,X_test, y_test):
    plt.style.use('seaborn-v0_8-darkgrid')
    fig, ax = plt.subplots(figsize=(16,12))
    pprc = plot_precision_recall_curve(model,X_test,y_test,ax=ax)
    if not os.path.exists('images'):
        os.makedirs('images')
    plt.savefig('images/precision_recall_curve.png',facecolor='white', transparent=False)
    plt.show()

# %%
          
df = load_data()
metric = manual_train_estimator(df)
plot_metrics(metric)
# Out:
# X train set size: (36240, 3);
# X test set size: (17850, 3);
# y train set size: (36240,);
# y test set size: (17850,);
# Counter({0: 53899, 1: 191})
# scale_pos_weight: 282.194

# %%
# Tuning the hyperparameters of the LightGBM algorithm
tuned_params = get_tuned_params(df)
# Out:
# X train set size: (36240, 3);
# X test set size: (17850, 3);
# y train set size: (36240,);
# y test set size: (17850,);
# Counter({0: 53899, 1: 191})
# scale_pos_weight: 282.194
#
#  * Initiating LGBMTuner.fit
#      . Settings:
#      .. Trying 1000 trials
#      .. Evaluation metric: f1
#      .. Study direction: minimize log_loss
#
#      . Trial number: 0 finished
#      .. Optimization score (lower-better): log_loss: 0.020310250849547757
#      .. Evaluation score (greater-better): f1: 0.2222222222222222
#  ...........................................................................
#      . Trial number: 1 finished
#      .. Optimization score (lower-better): log_loss: 0.022093305139603153
#      .. Evaluation score (greater-better): f1: 0.2222222222222222
#  ...........................................................................
#      . Trial number: 2 finished
#      .. Optimization score (lower-better): log_loss: 0.021984327826535303
#      .. Evaluation score (greater-better): f1: 0.0
#  ...........................................................................
#      . Trial number: 3 finished
#      .. Optimization score (lower-better): log_loss: 0.022271318968845506
#      .. Evaluation score (greater-better): f1: 0.0
#  ...........................................................................
#      . Trial number: 4 finished
#      .. Optimization score (lower-better): log_loss: 0.021808150812884574
#      .. Evaluation score (greater-better): f1: 0.0
#  ...........................................................................
#      . Trial number: 10 finished
#      .. Optimization score (lower-better): log_loss: 0.021296062399280447
#      .. Evaluation score (greater-better): f1: 0.17142857142857143
#  ...........................................................................
#      . Trial number: 11 finished
#      .. Optimization score (lower-better): log_loss: 0.02013919315689169
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 12 finished
#      .. Optimization score (lower-better): log_loss: 0.020351621813829046
#      .. Evaluation score (greater-better): f1: 0.2222222222222222
#  ...........................................................................
#      . Trial number: 16 finished
#      .. Optimization score (lower-better): log_loss: 0.0202732856433055
#      .. Evaluation score (greater-better): f1: 0.2222222222222222
#  ...........................................................................
#      . Trial number: 17 finished
#      .. Optimization score (lower-better): log_loss: 0.020233922254224854
#      .. Evaluation score (greater-better): f1: 0.2222222222222222
#  ...........................................................................
#      . Trial number: 19 finished
#      .. Optimization score (lower-better): log_loss: 0.018693636685451053
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 20 finished
#      .. Optimization score (lower-better): log_loss: 0.019302754885510583
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 21 finished
#      .. Optimization score (lower-better): log_loss: 0.01863706808888199
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 27 finished
#      .. Optimization score (lower-better): log_loss: 0.0194139430407597
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 30 finished
#      .. Optimization score (lower-better): log_loss: 0.02004397820641173
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 35 finished
#      .. Optimization score (lower-better): log_loss: 0.02014606326417314
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 55 finished
#      .. Optimization score (lower-better): log_loss: 0.019616219196233915
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 56 finished
#      .. Optimization score (lower-better): log_loss: 0.01936161146714643
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 58 finished
#      .. Optimization score (lower-better): log_loss: 0.019765593601299376
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 60 finished
#      .. Optimization score (lower-better): log_loss: 0.01913098586732886
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 68 finished
#      .. Optimization score (lower-better): log_loss: 0.019764605314049256
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 79 finished
#      .. Optimization score (lower-better): log_loss: 0.020138714208917417
#      .. Evaluation score (greater-better): f1: 0.0
#  ...........................................................................
#      . Trial number: 105 finished
#      .. Optimization score (lower-better): log_loss: 0.019326558938197395
#      .. Evaluation score (greater-better): f1: 0.2702702702702703
#  ...........................................................................
#      . Trial number: 112 finished
#      .. Optimization score (lower-better): log_loss: 0.018337809491523253
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 115 finished
#      .. Optimization score (lower-better): log_loss: 0.01927923228620321
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 131 finished
#      .. Optimization score (lower-better): log_loss: 0.019265170730157807
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 133 finished
#      .. Optimization score (lower-better): log_loss: 0.019798988684120597
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 137 finished
#      .. Optimization score (lower-better): log_loss: 0.019082945543258116
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 145 finished
#      .. Optimization score (lower-better): log_loss: 0.017911750345367936
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 194 finished
#      .. Optimization score (lower-better): log_loss: 0.018923913086675376
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 195 finished
#      .. Optimization score (lower-better): log_loss: 0.019070377717308205
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 196 finished
#      .. Optimization score (lower-better): log_loss: 0.017455077420166238
#      .. Evaluation score (greater-better): f1: 0.4
#  ...........................................................................
#      . Trial number: 217 finished
#      .. Optimization score (lower-better): log_loss: 0.019353025008508353
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 281 finished
#      .. Optimization score (lower-better): log_loss: 0.018196054406340402
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 299 finished
#      .. Optimization score (lower-better): log_loss: 0.019345295598845975
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 375 finished
#      .. Optimization score (lower-better): log_loss: 0.018433438548264243
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 439 finished
#      .. Optimization score (lower-better): log_loss: 0.018163743990232288
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 480 finished
#      .. Optimization score (lower-better): log_loss: 0.01910369606250686
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 489 finished
#      .. Optimization score (lower-better): log_loss: 0.018909388291420852
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 500 finished
#      .. Optimization score (lower-better): log_loss: 0.018519320764450616
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 596 finished
#      .. Optimization score (lower-better): log_loss: 0.019162544501443425
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 600 finished
#      .. Optimization score (lower-better): log_loss: 0.01929883022141139
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 616 finished
#      .. Optimization score (lower-better): log_loss: 0.018776860504905613
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 619 finished
#      .. Optimization score (lower-better): log_loss: 0.01861528094922719
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 623 finished
#      .. Optimization score (lower-better): log_loss: 0.019058490351622194
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 654 finished
#      .. Optimization score (lower-better): log_loss: 0.01889775177797849
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 666 finished
#      .. Optimization score (lower-better): log_loss: 0.01908777452455518
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 715 finished
#      .. Optimization score (lower-better): log_loss: 0.018559167871496675
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 719 finished
#      .. Optimization score (lower-better): log_loss: 0.01843280955631606
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 787 finished
#      .. Optimization score (lower-better): log_loss: 0.019136262343006763
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#      . Trial number: 818 finished
#      .. Optimization score (lower-better): log_loss: 0.018770319121496272
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 819 finished
#      .. Optimization score (lower-better): log_loss: 0.01891319488862898
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 861 finished
#      .. Optimization score (lower-better): log_loss: 0.019162392741680294
#      .. Evaluation score (greater-better): f1: 0.358974358974359
#  ...........................................................................
#      . Trial number: 882 finished
#      .. Optimization score (lower-better): log_loss: 0.018857272448291988
#      .. Evaluation score (greater-better): f1: 0.4
#  ...........................................................................
#      . Trial number: 988 finished
#      .. Optimization score (lower-better): log_loss: 0.018217523683904994
#      .. Evaluation score (greater-better): f1: 0.43902439024390244
#  ...........................................................................
#      . Trial number: 990 finished
#      .. Optimization score (lower-better): log_loss: 0.018672744884752488
#      .. Evaluation score (greater-better): f1: 0.4
#  ...........................................................................
#      . Trial number: 996 finished
#      .. Optimization score (lower-better): log_loss: 0.01889826692317025
#      .. Evaluation score (greater-better): f1: 0.3157894736842105
#  ...........................................................................
#
#    - Tune n_estimators with early_stopping
# Training until validation scores don't improve for 200 rounds
# [100]	train's lgb_f1: 0.222222	valid's lgb_f1: 0.117647
# [200]	train's lgb_f1: 0.222222	valid's lgb_f1: 0.117647
# Early stopping, best iteration is:
# [18]	train's lgb_f1: 0.222222	valid's lgb_f1: 0.117647
#
#    - Fitting optimized model with the follwing params:
# task                             : train
# learning_rate                    : 0.03
# num_leaves                       : 212
# colsample_bytree                 : 0.8693890024459053
# subsample                        : 0.88304515985001
# bagging_freq                     : 1
# max_depth                        : -1
# verbosity                        : -1
# reg_alpha                        : 4.547489199721143e-06
# reg_lambda                       : 0.001098068035148366
# min_split_gain                   : 0.0
# zero_as_missing                  : False
# max_bin                          : 255
# min_data_in_bin                  : 3
# random_state                     : 42
# device_type                      : cpu
# num_classes                      : 1
# objective                        : binary
# metric                           : binary_logloss
# num_threads                      : 10
# min_sum_hessian_in_leaf          : 0.07194646531322837
# n_estimators                     : 18
#      . Optuna hyperparameters optimization finished
#      .. Best trial number:196    |     log_loss:         0.017455077420166238
#  ---------------------------------------------------------------------------
#      . n_estimators optimization finished
#      .. best iteration:   18   |     f1:          0.11764705882352941
#  ===========================================================================
#
# Time elapsed for fit execution: 1 min 25.674 sec
# Best parameters: {'task': 'train', 'learning_rate': 0.03, 'num_leaves': 212, 'colsample_bytree': 0.8693890024459053, 'subsample': 0.88304515985001, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 4.547489199721143e-06, 'reg_lambda': 0.001098068035148366, 'min_split_gain': 0.0, 'zero_as_missing': False, 'max_bin': 255, 'min_data_in_bin': 3, 'random_state': 42, 'device_type': 'cpu', 'num_classes': 1, 'objective': 'binary', 'metric': 'binary_logloss', 'num_threads': 10, 'min_sum_hessian_in_leaf': 0.07194646531322837, 'n_estimators': 18}
# Accuracy of LightGBM classifier is: 0.9965266106442577
# Precision Score of LightGBM classifier is: 1.0
# Recall Score of LightGBM classifier is: 0.015873015873015872
# F1 Score of LightGBM classifier is: 0.03125
# mse: 0.003473389355742297
# mae: 0.003473389355742297

# %%
import mlflow
from mlflow.tracking import MlflowClient
exp_name = "LightGBM_autolog_Fraud_Model"
# Initialize client and experiment
client = MlflowClient()
mlflow.set_experiment(exp_name)
exp = client.get_experiment_by_name(exp_name)
# Absolute 
abs_path = os.path.dirname(os.path.abspath('model.ipynb'))
img_path = os.path.join(abs_path, 'images')
# Start a new run in the experiment and track 
with mlflow.start_run(experiment_id=exp.experiment_id):
     #Set model description
     mlflow.set_tag('mlflow.note.content',"Model to predict fraud transactions")   
     mlflow.lightgbm.autolog(registered_model_name=exp_name) 
     y_test,y_pred,model,acc,precision,recall,score_f1,mse,mae = best_train_estimator(df,tuned_params)
     mlflow.log_metric("Accuracy",acc)
     mlflow.log_metric("Precision",precision)
     mlflow.log_metric("Recall",recall)
     mlflow.log_metric("F1 Score",score_f1)
     mlflow.log_metric("MSE",mse)
     mlflow.log_metric("MAE",mae)
     confusion_matrix_plot(y_test,y_pred)
     mlflow.log_artifact(img_path)
     autolog_run= mlflow.active_run()
     autolog_run_id = mlflow.last_active_run().info.run_id
     # mlflow.register_model(f"runs:/{autolog_run_id}",exp_name)
mlflow.end_run()
# Out:
# X train set size: (36240, 3);
# X test set size: (17850, 3);
# y train set size: (36240,);
# y test set size: (17850,);
# Counter({0: 53899, 1: 191})
# scale_pos_weight: 282.194
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.07194646531322837, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.07194646531322837
# [LightGBM] [Warning] num_threads is set=10, n_jobs=-1 will be ignored. Current value: num_threads=10
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# Successfully registered model 'LightGBM_autolog_Fraud_Model'.
# 2023/03/20 21:27:19 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: LightGBM_autolog_Fraud_Model, version 1
# Created version '1' of model 'LightGBM_autolog_Fraud_Model'.
# Best parameters: {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 0.8693890024459053, 'importance_type': 'split', 'learning_rate': 0.03, 'max_depth': -1, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 18, 'n_jobs': -1, 'num_leaves': 212, 'objective': 'binary', 'random_state': 42, 'reg_alpha': 4.547489199721143e-06, 'reg_lambda': 0.001098068035148366, 'silent': 'warn', 'subsample': 0.88304515985001, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'scale_pos_weight': 282.1937172774869, 'task': 'train', 'bagging_freq': 1, 'verbosity': -1, 'zero_as_missing': False, 'max_bin': 255, 'min_data_in_bin': 3, 'device_type': 'cpu', 'num_classes': 1, 'metric': 'binary_logloss', 'num_threads': 10, 'min_sum_hessian_in_leaf': 0.07194646531322837}
# Accuracy of LightGBM classifier is: 0.8012324929971989
# Precision Score of LightGBM classifier is: 0.0073508623126943735
# Recall Score of LightGBM classifier is: 0.4126984126984127
# F1 Score of LightGBM classifier is: 0.014444444444444444
# mse: 0.19876750700280113
# mae: 0.19876750700280113

# %%
# Function to change the stage of the model
def change_stage():
    client = MlflowClient()
    client.update_model_version(name=exp_name,version=1  ,description="Model to predict fraud transactions")
    client.transition_model_version_stage(
            name=exp_name,
            version=1,
            #  Staging|Archived|Production|None
            stage="Production"      
        )
change_stage()

# %%
# Fuction to make predictions using the model
def predict():
    X, y = get_variables(df)
    X_train, X_test, y_train, y_test = make_train_test_split(X,y)

    model_name = exp_name 
    model_version = 1

    model = mlflow.pyfunc.load_model(
        model_uri=f"models:/{model_name}/{model_version}"
    )

    return model.predict(X_test[0:1000])

type(predict())
# Out:
# X train set size: (36240, 3);
# X test set size: (17850, 3);
# y train set size: (36240,);
# y test set size: (17850,);
# numpy.ndarray

# %%
# Create an API to serve the model using Docker
export MLFLOW_TRACKING_URI=http://localhost:5000

mlflow models serve -m "models:/LightGBM_autolog_Fraud_Model/Production"
